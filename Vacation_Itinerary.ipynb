# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import gmaps.datasets
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

# Import the requests library
import requests

# Import the API key
from config import weather_api_key
from config import g_key
gmaps.configure(api_key=g_key)

# %%
# import cities from Part 2
cities_to_load = "weather_data/WeatherPy_vacation.csv"

# %%
# Create new dataframe from damp_cities.csv
vacation_cities_data_df = pd.read_csv(cities_to_load)
vacation_cities_data_df
# Out:
#      Weather_Challenge_p2          City Country  Max Temp Current Description  \
# 0                       2     Jamestown      AU     65.59           clear sky
# 1                       4    Zhezkazgan      KZ     41.77     overcast clouds
# 2                       5   New Norfolk      AU     63.00          few clouds
# 3                       6  Port Lincoln      AU     61.72           clear sky
# 4                      10    Bredasdorp      ZA     64.00     overcast clouds
# ..                    ...           ...     ...       ...                 ...
# 256                   563        Lyndon      US     64.40           clear sky
# 257                   567      Qaqortoq      GL     48.20          light snow
# 258                   568       Yangcun      CN     55.99          few clouds
# 259                   569       Aasiaat      GL     31.98     overcast clouds
# 260                   573        Darhan      MN     30.27          light snow
#
#        Lat     Lng                       Hotel Name
# 0   -33.21  138.60         Jamestown Motel Terraces
# 1    47.80   67.71             Kvartiry Posutochno.
# 2   -42.78  147.06  The Shingles Riverside Cottages
# 3   -34.72  135.86               Port Lincoln Hotel
# 4   -34.53   20.04         Bredasdorp Country Manor
# ..     ...     ...                              ...
# 256  38.61  -95.68                              NaN
# 257  60.72  -46.03                              NaN
# 258  29.98  118.17                              NaN
# 259  68.71  -52.87                              NaN
# 260  49.49  105.92                              NaN
#
# [261 rows x 8 columns]

# %%
# Create coordinate tuple and add to travel_itinerary DF
coord_tuple = list(zip(  vacation_cities_data_df.Lat,  vacation_cities_data_df.Lng  ))
coord_tuple
# Out:
# [(-33.21, 138.6),
#  (47.8, 67.71),
#  (-42.78, 147.06),
#  (-34.72, 135.86),
#  (-34.53, 20.04),
#  (-54.81, -68.31),
#  (40.65, 47.48),
#  (15.34, 74.49),
#  (-53.16, -70.91),
#  (51.0, 81.46),
#  (60.14, -45.24),
#  (42.65, -73.75),
#  (44.76, -85.62),
#  (32.19, 130.02),
#  (8.96, 38.73),
#  (39.95, -94.76),
#  (59.5, 26.52),
#  (36.62, 101.77),
#  (60.91, -46.05),
#  (-30.97, 22.13),
#  (-20.34, 57.76),
#  (-33.64, 115.35),
#  (-34.42, 19.24),
#  (59.92, 16.61),
#  (59.79, 5.78),
#  (27.93, 96.16),
#  (49.0, -64.4),
#  (49.12, -68.38),
#  (47.68, 15.94),
#  (37.18, 33.22),
#  (-38.31, -60.23),
#  (59.12, 11.39),
#  (65.61, -37.64),
#  (32.58, -88.19),
#  (40.22, 116.23),
#  (-33.59, 26.89),
#  (-22.09, -70.2),
#  (13.65, 43.82),
#  (50.41, 3.68),
#  (35.54, 106.68),
#  (43.2, -8.36),
#  (-33.93, 18.42),
#  (36.86, 70.83),
#  (-29.95, -71.34),
#  (45.58, -122.35),
#  (-46.43, -67.52),
#  (61.05, 43.9),
#  (49.76, 16.66),
#  (27.18, 31.19),
#  (37.17, -99.65),
#  (58.75, 17.01),
#  (-11.1, -77.61),
#  (39.31, -74.98),
#  (50.68, 156.12),
#  (51.91, -8.17),
#  (33.08, -16.33),
#  (57.43, 56.94),
#  (26.1, 107.47),
#  (-0.22, -78.51),
#  (43.02, 143.2),
#  (-34.0, 24.73),
#  (38.94, 100.46),
#  (41.62, 24.49),
#  (38.9, -98.86),
#  (62.16, -7.17),
#  (33.37, 134.14),
#  (54.1, 36.24),
#  (-44.7, 169.14),
#  (60.15, -1.15),
#  (37.14, -8.45),
#  (63.05, 179.32),
#  (-17.39, -66.16),
#  (55.34, -131.65),
#  (41.4, 27.36),
#  (-5.09, -81.11),
#  (43.97, -111.68),
#  (29.04, 114.56),
#  (23.48, 111.3),
#  (29.7, -9.73),
#  (64.86, -147.8),
#  (-34.61, -58.44),
#  (40.81, 111.65),
#  (-34.91, -54.96),
#  (43.37, -124.22),
#  (59.1, 26.19),
#  (-34.85, 139.16),
#  (-28.55, 16.43),
#  (35.37, 132.75),
#  (28.87, 75.92),
#  (24.18, 117.61),
#  (-34.5, 137.49),
#  (34.45, 40.92),
#  (39.62, -77.74),
#  (55.83, 56.91),
#  (-38.55, -58.74),
#  (41.89, 12.48),
#  (31.86, 10.98),
#  (63.84, -22.43),
#  (57.8, 158.67),
#  (45.12, 124.86),
#  (37.35, -108.58),
#  (58.3, -134.42),
#  (-22.12, 14.28),
#  (32.41, -87.02),
#  (34.32, 47.07),
#  (-36.08, 146.92),
#  (50.81, 37.2),
#  (64.17, -51.74),
#  (36.95, 36.2),
#  (43.31, -73.64),
#  (-19.16, 46.8),
#  (20.68, 76.21),
#  (39.28, 141.86),
#  (52.93, 54.74),
#  (46.42, 3.91),
#  (22.82, 115.83),
#  (-29.12, 26.22),
#  (35.01, 37.05),
#  (43.11, 144.15),
#  (51.18, 32.81),
#  (-35.71, 150.18),
#  (44.99, 124.06),
#  (25.52, 85.32),
#  (41.28, -70.1),
#  (61.99, -49.67),
#  (41.71, -86.9),
#  (46.68, 113.28),
#  (36.27, 2.77),
#  (46.32, 132.2),
#  (48.1, 20.79),
#  (27.21, 60.69),
#  (42.73, 133.08),
#  (38.61, -95.68),
#  (60.72, -46.03),
#  (29.98, 118.17),
#  (68.71, -52.87),
#  (49.49, 105.92)]

# %%
# Add coordiante tuple to existing DF
vacation_cities_data_df["Coordinate Tuple"]= coord_tuple
vacation_cities_data_df.head()
# Out:
#    Weather_Challenge_p2          City Country  Max Temp Current Description  \
# 0                     2     Jamestown      AU     65.59           clear sky
# 1                     4    Zhezkazgan      KZ     41.77     overcast clouds
# 2                     5   New Norfolk      AU     63.00          few clouds
# 3                     6  Port Lincoln      AU     61.72           clear sky
# 4                    10    Bredasdorp      ZA     64.00     overcast clouds
#
#      Lat     Lng                       Hotel Name  Coordinate Tuple
# 0 -33.21  138.60         Jamestown Motel Terraces   (-33.21, 138.6)
# 1  47.80   67.71             Kvartiry Posutochno.     (47.8, 67.71)
# 2 -42.78  147.06  The Shingles Riverside Cottages  (-42.78, 147.06)
# 3 -34.72  135.86               Port Lincoln Hotel  (-34.72, 135.86)
# 4 -34.53   20.04         Bredasdorp Country Manor   (-34.53, 20.04)

# %%
# Create a filtered DF for the travel itinerary (lat & lng filter)

travel_itinerary_df = vacation_cities_data_df.loc[(vacation_cities_data_df["Lat"] > 48.8) & \
                                                 (vacation_cities_data_df["Lat"] < 51.0) & \
                                                  (vacation_cities_data_df["Lng"] > 0) &
                                                 (vacation_cities_data_df["Lng"] < 16)]


travel_itinerary_df
# Out:
#      Weather_Challenge_p2          City Country  Max Temp Current Description  \
# 38                     88     Quievrain      BE     39.20           clear sky
# 59                    132         Paris      FR     44.01          light rain
# 119                   276  Saint-Pierre      FR     39.99       broken clouds
# 159                   356           Aue      DE     36.00          few clouds
#
#        Lat    Lng                                      Hotel Name  \
# 38   50.41   3.68                        Logis Auberge le XIX ème
# 59   48.86   2.35  Citadines Les Halles Paris (Apart Hotel Paris)
# 119  48.95   4.24                            Auberge des Moissons
# 159  50.59  12.70                              Hotel Blauer Engel
#
#     Coordinate Tuple
# 38     (50.41, 3.68)
# 59     (48.86, 2.35)
# 119    (48.95, 4.24)
# 159    (50.59, 12.7)

# %%
# reset travel_itin DF index to ease pulling tuple info
travel_itinerary_df = travel_itinerary_df.reset_index(drop=True)
travel_itinerary_df
# Out:
#    Weather_Challenge_p2          City Country  Max Temp Current Description  \
# 0                    88     Quievrain      BE     39.20           clear sky
# 1                   132         Paris      FR     44.01          light rain
# 2                   276  Saint-Pierre      FR     39.99       broken clouds
# 3                   356           Aue      DE     36.00          few clouds
#
#      Lat    Lng                                      Hotel Name  \
# 0  50.41   3.68                        Logis Auberge le XIX ème
# 1  48.86   2.35  Citadines Les Halles Paris (Apart Hotel Paris)
# 2  48.95   4.24                            Auberge des Moissons
# 3  50.59  12.70                              Hotel Blauer Engel
#
#   Coordinate Tuple
# 0    (50.41, 3.68)
# 1    (48.86, 2.35)
# 2    (48.95, 4.24)
# 3    (50.59, 12.7)

# %%
# Assign travel stops by pulling tuple info from DF

start_loca = travel_itinerary_df.loc[0, "Coordinate Tuple"]
first_stop = travel_itinerary_df.loc[1, "Coordinate Tuple"]
second_stop = travel_itinerary_df.loc[2, "Coordinate Tuple"]
final_stop = travel_itinerary_df.loc[3, "Coordinate Tuple"]

# %%
# Add pop-up marker to map

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# Store the DataFrame Row
hotel_info = [info_box_template.format(**row)for index, row in travel_itinerary_df.iterrows()]

# %%
# Add a pop-up marker for each city
travel_stops = travel_itinerary_df[["Lat", "Lng"]]

marker_layer = gmaps.marker_layer(travel_stops, info_box_content=hotel_info)

# %%
# Use Latitude-longitude pairs as travel points & waypoints, add marker layer

waypoints = [first_stop, second_stop]

fig = gmaps.figure()
travel_stops = gmaps.directions_layer(start_loca, final_stop, waypoints = waypoints,travel_mode='DRIVING')
# Add layers
fig.add_layer(travel_stops)


fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Take a screenshot of the route and save it as WeatherPy_travel_map.png.

plt.savefig("weather_data/M6_images/WeatherPy_travel_map.png")

# %%
# Use Latitude-longitude pairs as travel points & waypoints, add marker layer

waypoints = [first_stop, second_stop]

fig = gmaps.figure()
travel_stops = gmaps.directions_layer(start_loca, final_stop, waypoints = waypoints,travel_mode='DRIVING')

# Add layers

fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Take a screenshot of the marker layer map for the route and save it as WeatherPy_travel_map_markers.png.

plt.savefig("weather_data/M6_images/WeatherPy_travel_map_markers.png")

# %% [markdown]
# # TBD - see about "bundling layers" for travel and market

# %%
# Use Latitude-longitude pairs as travel points & waypoints, add marker layer

waypoints = [first_stop, second_stop]

fig = gmaps.figure()
travel_stops = gmaps.directions_layer(start_loca, final_stop, waypoints = waypoints,travel_mode='DRIVING')
# Add layers
fig.add_layer(travel_stops)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
