# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

# Import the requests library
import requests

# Import the API key
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each of the latitude and longitude combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=12541dcd367261fc7c2e2e12a500423a

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        
        city_main = city_weather['weather'][0]['main']
        city_description = city_weather['weather'][0]['description']

        
        city_max_temp = city_weather["main"]['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather["sys"]["country"]

        
        # Try-except Rain block
        try: 
            city_rain = city_weather['rain']['3h']
            
        except:
            city_rain = 0
                
        # Try-except Snow block
        try: 
            city_snow = city_weather['snow']['3h'].astype(float)
            
        except:
            city_snow = 0
                
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information itno city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat, 
                         "Lng": city_lng, 
                         "Max Temp": city_max_temp, 
                         "Humidity": city_humidity, 
                         "Cloudiness": city_clouds, 
                         "Wind Speed": city_wind, 
                         "Country": city_country, 
                         "Date": city_date, 
                         "Current Main": city_main, 
                         "Current Description": city_description, 
                         "Rain inches (last 3 hrs)": city_rain, 
                         "Snow inches (last 3 hrs)": city_snow})

# If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Processing Record 1 of Set 1 | chutung
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | kaeo
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | arlit
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | wakkanai
# Processing Record 13 of Set 1 | ixtapa
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | saiha
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | bambanglipuro
# Processing Record 22 of Set 1 | makakilo city
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | aasiaat
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | ziezmariai
# Processing Record 28 of Set 1 | chok chai
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | san quintin
# Processing Record 31 of Set 1 | sola
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | urumqi
# City not found. Skipping...
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | yuzhnyy
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | burica
# City not found. Skipping...
# Processing Record 39 of Set 1 | eureka
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | itacare
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | agadez
# Processing Record 45 of Set 1 | labuhan
# Processing Record 46 of Set 1 | porbandar
# Processing Record 47 of Set 1 | buy
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | canora
# Processing Record 3 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 2 | olinda
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | atar
# Processing Record 7 of Set 2 | atherton
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | leshukonskoye
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | hamilton
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | kailua
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | saint-augustin
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | akyab
# City not found. Skipping...
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | moberly
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | puerto escondido
# Processing Record 26 of Set 2 | store heddinge
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | chiang rai
# Processing Record 29 of Set 2 | san cristobal
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | srednekolymsk
# Processing Record 32 of Set 2 | parnarama
# Processing Record 33 of Set 2 | tura
# Processing Record 34 of Set 2 | vicuna
# City not found. Skipping...
# Processing Record 35 of Set 2 | viedma
# Processing Record 36 of Set 2 | negombo
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | rio gallegos
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 41 of Set 2 | opoczno
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | vanavara
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | panzhihua
# Processing Record 48 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | nova vicosa
# Processing Record 2 of Set 3 | muisne
# Processing Record 3 of Set 3 | buraydah
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | mareeba
# Processing Record 7 of Set 3 | fort nelson
# Processing Record 8 of Set 3 | iqaluit
# Processing Record 9 of Set 3 | coquimbo
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | rorvik
# Processing Record 12 of Set 3 | capinota
# Processing Record 13 of Set 3 | henties bay
# Processing Record 14 of Set 3 | salinopolis
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | brigantine
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | vrangel
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | sladkovo
# Processing Record 24 of Set 3 | amga
# Processing Record 25 of Set 3 | okhotsk
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | araouane
# Processing Record 28 of Set 3 | garowe
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | sozopolis
# City not found. Skipping...
# Processing Record 31 of Set 3 | elat
# Processing Record 32 of Set 3 | catuday
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | sur
# Processing Record 35 of Set 3 | nabire
# Processing Record 36 of Set 3 | gasa
# Processing Record 37 of Set 3 | kupang
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | havoysund
# Processing Record 40 of Set 3 | venancio aires
# Processing Record 41 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 3 | clovis
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | jiuquan
# Processing Record 45 of Set 3 | shelburne
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | chara
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | codrington
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | touros
# Processing Record 2 of Set 4 | olafsvik
# City not found. Skipping...
# Processing Record 3 of Set 4 | leopold
# Processing Record 4 of Set 4 | isla vista
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 4 | tiarei
# Processing Record 9 of Set 4 | grand-santi
# Processing Record 10 of Set 4 | mindelo
# Processing Record 11 of Set 4 | lyuban
# Processing Record 12 of Set 4 | coahuayana
# Processing Record 13 of Set 4 | svetlogorsk
# Processing Record 14 of Set 4 | qafsah
# City not found. Skipping...
# Processing Record 15 of Set 4 | isiro
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | adrar
# Processing Record 18 of Set 4 | farah
# Processing Record 19 of Set 4 | conde
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | prado
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | evensk
# Processing Record 24 of Set 4 | agde
# Processing Record 25 of Set 4 | cayenne
# Processing Record 26 of Set 4 | tevriz
# Processing Record 27 of Set 4 | rawson
# Processing Record 28 of Set 4 | amapa
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | nacogdoches
# Processing Record 31 of Set 4 | kirkenes
# Processing Record 32 of Set 4 | evanston
# Processing Record 33 of Set 4 | christchurch
# Processing Record 34 of Set 4 | asfi
# City not found. Skipping...
# Processing Record 35 of Set 4 | fairbanks
# Processing Record 36 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 4 | bato
# Processing Record 39 of Set 4 | akom
# Processing Record 40 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | san angelo
# Processing Record 44 of Set 4 | oyem
# Processing Record 45 of Set 4 | xinzhou
# Processing Record 46 of Set 4 | nisia floresta
# Processing Record 47 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | roebourne
# Processing Record 50 of Set 4 | hilo
# Processing Record 1 of Set 5 | khania
# City not found. Skipping...
# Processing Record 2 of Set 5 | coihaique
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | khani
# Processing Record 6 of Set 5 | khalkhal
# Processing Record 7 of Set 5 | iquique
# Processing Record 8 of Set 5 | yar-sale
# Processing Record 9 of Set 5 | bubaque
# Processing Record 10 of Set 5 | ukiah
# Processing Record 11 of Set 5 | cururupu
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | briancon
# Processing Record 14 of Set 5 | viradouro
# Processing Record 15 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | batsfjord
# Processing Record 18 of Set 5 | bara
# Processing Record 19 of Set 5 | dubbo
# Processing Record 20 of Set 5 | balakovo
# Processing Record 21 of Set 5 | tukrah
# City not found. Skipping...
# Processing Record 22 of Set 5 | nalut
# Processing Record 23 of Set 5 | chiknayakanhalli
# Processing Record 24 of Set 5 | avarua
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 5 | castro
# Processing Record 28 of Set 5 | puertollano
# Processing Record 29 of Set 5 | altus
# Processing Record 30 of Set 5 | soeng sang
# Processing Record 31 of Set 5 | okha
# Processing Record 32 of Set 5 | dharchula
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | high level
# Processing Record 35 of Set 5 | kloulklubed
# Processing Record 36 of Set 5 | tibati
# Processing Record 37 of Set 5 | charleston
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | mahebourg
# Processing Record 40 of Set 5 | cuamba
# Processing Record 41 of Set 5 | thinadhoo
# Processing Record 42 of Set 5 | mikhaylovka
# Processing Record 43 of Set 5 | wajir
# Processing Record 44 of Set 5 | mantena
# Processing Record 45 of Set 5 | waipawa
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | itarema
# Processing Record 49 of Set 5 | jaramana
# City not found. Skipping...
# Processing Record 50 of Set 5 | bolgatanga
# Processing Record 1 of Set 6 | salme
# Processing Record 2 of Set 6 | dingle
# Processing Record 3 of Set 6 | inta
# Processing Record 4 of Set 6 | mayuge
# Processing Record 5 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | eten
# Processing Record 8 of Set 6 | viamao
# Processing Record 9 of Set 6 | ketchikan
# Processing Record 10 of Set 6 | kununurra
# Processing Record 11 of Set 6 | aimores
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | bambous virieux
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | korgen
# Processing Record 17 of Set 6 | morondava
# Processing Record 18 of Set 6 | beipiao
# Processing Record 19 of Set 6 | barra patuca
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | saint-louis
# Processing Record 22 of Set 6 | port blair
# Processing Record 23 of Set 6 | mahon
# Processing Record 24 of Set 6 | abu dhabi
# Processing Record 25 of Set 6 | najran
# Processing Record 26 of Set 6 | payson
# Processing Record 27 of Set 6 | port-gentil
# Processing Record 28 of Set 6 | rio grande
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | taga
# Processing Record 31 of Set 6 | knysna
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | glowno
# Processing Record 34 of Set 6 | minudasht
# Processing Record 35 of Set 6 | bannu
# Processing Record 36 of Set 6 | flin flon
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | agirish
# Processing Record 39 of Set 6 | chiang khong
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | saint-pierre
# Processing Record 42 of Set 6 | anadyr
# Processing Record 43 of Set 6 | waitati
# Processing Record 44 of Set 6 | yuzhno-kurilsk
# Processing Record 45 of Set 6 | polewali
# Processing Record 46 of Set 6 | novi sanzhary
# Processing Record 47 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | yatou
# Processing Record 50 of Set 6 | gorontalo
# Processing Record 1 of Set 7 | aklavik
# Processing Record 2 of Set 7 | povenets
# Processing Record 3 of Set 7 | kopyevo
# City not found. Skipping...
# Processing Record 4 of Set 7 | anchorage
# Processing Record 5 of Set 7 | atlantis
# Processing Record 6 of Set 7 | gladstone
# Processing Record 7 of Set 7 | sistranda
# Processing Record 8 of Set 7 | praia da vitoria
# Processing Record 9 of Set 7 | hyeres
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | baykit
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | dwarka
# Processing Record 16 of Set 7 | westport
# Processing Record 17 of Set 7 | campbell river
# Processing Record 18 of Set 7 | bonthe
# Processing Record 19 of Set 7 | iranshahr
# Processing Record 20 of Set 7 | bayanday
# Processing Record 21 of Set 7 | destin
# Processing Record 22 of Set 7 | kelo
# City not found. Skipping...
# Processing Record 23 of Set 7 | bhatkal
# Processing Record 24 of Set 7 | igarka
# Processing Record 25 of Set 7 | ballina
# Processing Record 26 of Set 7 | raudeberg
# Processing Record 27 of Set 7 | bonavista
# Processing Record 28 of Set 7 | ust-nera
# Processing Record 29 of Set 7 | airai
# Processing Record 30 of Set 7 | kulu
# Processing Record 31 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 7 | polson
# Processing Record 34 of Set 7 | abinsk
# Processing Record 35 of Set 7 | aswan
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | kankaanpaa
# Processing Record 38 of Set 7 | marzuq
# Processing Record 39 of Set 7 | husavik
# Processing Record 40 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 41 of Set 7 | ewo
# Processing Record 42 of Set 7 | minas
# Processing Record 43 of Set 7 | dongsheng
# Processing Record 44 of Set 7 | lima
# Processing Record 45 of Set 7 | teterow
# Processing Record 46 of Set 7 | balotra
# Processing Record 47 of Set 7 | walvis bay
# Processing Record 48 of Set 7 | gizo
# Processing Record 49 of Set 7 | nantucket
# Processing Record 50 of Set 7 | tuy hoa
# Processing Record 1 of Set 8 | nanortalik
# Processing Record 2 of Set 8 | cherskiy
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | badou
# Processing Record 5 of Set 8 | norsup
# Processing Record 6 of Set 8 | talnakh
# Processing Record 7 of Set 8 | asau
# City not found. Skipping...
# Processing Record 8 of Set 8 | kulhudhuffushi
# Processing Record 9 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | mudanya
# Processing Record 12 of Set 8 | rafai
# Processing Record 13 of Set 8 | grand gaube
# Processing Record 14 of Set 8 | portland
# Processing Record 15 of Set 8 | blackwater
# Processing Record 16 of Set 8 | arys
# Processing Record 17 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 18 of Set 8 | guilin
# Processing Record 19 of Set 8 | araceli
# Processing Record 20 of Set 8 | selikhino
# Processing Record 21 of Set 8 | arraial do cabo
# Processing Record 22 of Set 8 | ayagoz
# Processing Record 23 of Set 8 | qiqihar
# Processing Record 24 of Set 8 | san patricio
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | mercedes
# Processing Record 27 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 8 | itupiranga
# Processing Record 30 of Set 8 | bathsheba
# Processing Record 31 of Set 8 | cockburn town
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | berlevag
# Processing Record 34 of Set 8 | esperance
# Processing Record 35 of Set 8 | korla
# City not found. Skipping...
# Processing Record 36 of Set 8 | clarence town
# Processing Record 37 of Set 8 | yulara
# Processing Record 38 of Set 8 | brawley
# Processing Record 39 of Set 8 | tabou
# Processing Record 40 of Set 8 | benjamin aceval
# Processing Record 41 of Set 8 | treuchtlingen
# Processing Record 42 of Set 8 | bang khla
# Processing Record 43 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 8 | caluquembe
# Processing Record 45 of Set 8 | marsh harbour
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | fare
# Processing Record 48 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 50 of Set 8 | nenjiang
# Processing Record 1 of Set 9 | umm lajj
# Processing Record 2 of Set 9 | isangel
# Processing Record 3 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 9 | port hedland
# Processing Record 5 of Set 9 | kudahuvadhoo
# Processing Record 6 of Set 9 | jauja
# Processing Record 7 of Set 9 | harer
# Processing Record 8 of Set 9 | puntarenas
# Processing Record 9 of Set 9 | lunenburg
# Processing Record 10 of Set 9 | sioux lookout
# Processing Record 11 of Set 9 | oranjemund
# Processing Record 12 of Set 9 | kushikino
# Processing Record 13 of Set 9 | medeiros neto
# Processing Record 14 of Set 9 | wasilla
# Processing Record 15 of Set 9 | cotonou
# Processing Record 16 of Set 9 | brownwood
# Processing Record 17 of Set 9 | krasnyye tkachi
# Processing Record 18 of Set 9 | vodnyy
# Processing Record 19 of Set 9 | negotin
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | goba
# Processing Record 22 of Set 9 | brae
# Processing Record 23 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 9 | vardo
# Processing Record 25 of Set 9 | pangnirtung
# Processing Record 26 of Set 9 | san juan
# Processing Record 27 of Set 9 | matagami
# Processing Record 28 of Set 9 | paraiso
# Processing Record 29 of Set 9 | dolores
# Processing Record 30 of Set 9 | san pedro
# Processing Record 31 of Set 9 | bar harbor
# Processing Record 32 of Set 9 | hay river
# Processing Record 33 of Set 9 | vostok
# Processing Record 34 of Set 9 | pargolovo
# Processing Record 35 of Set 9 | columbus
# Processing Record 36 of Set 9 | saratoga springs
# Processing Record 37 of Set 9 | kharan
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | playas
# Processing Record 40 of Set 9 | muli
# Processing Record 41 of Set 9 | taoudenni
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | liverpool
# Processing Record 44 of Set 9 | gazojak
# Processing Record 45 of Set 9 | qingquan
# Processing Record 46 of Set 9 | belyy yar
# Processing Record 47 of Set 9 | leningradskiy
# Processing Record 48 of Set 9 | pacific grove
# Processing Record 49 of Set 9 | mnogovershinnyy
# Processing Record 50 of Set 9 | gigmoto
# Processing Record 1 of Set 10 | porto novo
# Processing Record 2 of Set 10 | sao filipe
# Processing Record 3 of Set 10 | harindanga
# Processing Record 4 of Set 10 | jumla
# Processing Record 5 of Set 10 | vila
# Processing Record 6 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 7 of Set 10 | petropavlovka
# Processing Record 8 of Set 10 | eyl
# Processing Record 9 of Set 10 | faya
# Processing Record 10 of Set 10 | yzeure
# Processing Record 11 of Set 10 | jalu
# Processing Record 12 of Set 10 | micheweni
# Processing Record 13 of Set 10 | kavieng
# Processing Record 14 of Set 10 | amarante do maranhao
# Processing Record 15 of Set 10 | ipixuna
# Processing Record 16 of Set 10 | pyapon
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | slave lake
# Processing Record 19 of Set 10 | isakly
# Processing Record 20 of Set 10 | lufilufi
# Processing Record 21 of Set 10 | kondinskoye
# Processing Record 22 of Set 10 | solton
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | riom
# Processing Record 25 of Set 10 | gaspe
# Processing Record 26 of Set 10 | trelew
# Processing Record 27 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 28 of Set 10 | soyo
# Processing Record 29 of Set 10 | beatrice
# Processing Record 30 of Set 10 | sobolevo
# Processing Record 31 of Set 10 | zhoucheng
# Processing Record 32 of Set 10 | greenville
# Processing Record 33 of Set 10 | panguna
# Processing Record 34 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 10 | beaver dam
# Processing Record 36 of Set 10 | sambava
# Processing Record 37 of Set 10 | gurupi
# Processing Record 38 of Set 10 | nuuk
# Processing Record 39 of Set 10 | gunjur
# Processing Record 40 of Set 10 | hobyo
# Processing Record 41 of Set 10 | baruun-urt
# Processing Record 42 of Set 10 | cherkessk
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | yura
# Processing Record 45 of Set 10 | shelabolikha
# Processing Record 46 of Set 10 | omsukchan
# Processing Record 47 of Set 10 | dukat
# Processing Record 48 of Set 10 | scarborough
# Processing Record 49 of Set 10 | placido de castro
# Processing Record 50 of Set 10 | ron phibun
# Processing Record 1 of Set 11 | sechura
# Processing Record 2 of Set 11 | russell
# Processing Record 3 of Set 11 | kahama
# Processing Record 4 of Set 11 | zhezkazgan
# Processing Record 5 of Set 11 | mersing
# Processing Record 6 of Set 11 | angoche
# Processing Record 7 of Set 11 | derzhavinsk
# Processing Record 8 of Set 11 | rafaela
# Processing Record 9 of Set 11 | ilhabela
# Processing Record 10 of Set 11 | sorland
# Processing Record 11 of Set 11 | nara
# Processing Record 12 of Set 11 | poshekhonye
# Processing Record 13 of Set 11 | laredo
# Processing Record 14 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 15 of Set 11 | mount isa
# Processing Record 16 of Set 11 | ust-kalmanka
# Processing Record 17 of Set 11 | aripuana
# Processing Record 18 of Set 11 | lobito
# Processing Record 19 of Set 11 | ambovombe
# Processing Record 20 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 11 | constitucion
# Processing Record 22 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 11 | veraval
# Processing Record 24 of Set 11 | jardim
# Processing Record 25 of Set 11 | quatre cocos
# Processing Record 26 of Set 11 | mao
# Processing Record 27 of Set 11 | verkhnevilyuysk
# Processing Record 28 of Set 11 | bethel
# Processing Record 29 of Set 11 | moree
# Processing Record 30 of Set 11 | mayo
# Processing Record 31 of Set 11 | chapleau
# Processing Record 32 of Set 11 | zhigalovo
# Processing Record 33 of Set 11 | houma
# Processing Record 34 of Set 11 | puerto leguizamo
# Processing Record 35 of Set 11 | seoul
# Processing Record 36 of Set 11 | andilamena
# Processing Record 37 of Set 11 | san lawrenz
# Processing Record 38 of Set 11 | melbu
# Processing Record 39 of Set 11 | staryy nadym
# Processing Record 40 of Set 11 | luganville
# Processing Record 41 of Set 11 | chernyshevskiy
# Processing Record 42 of Set 11 | todos santos
# Processing Record 43 of Set 11 | san antonio
# Processing Record 44 of Set 11 | pedernales
# Processing Record 45 of Set 11 | cazaje
# City not found. Skipping...
# Processing Record 46 of Set 11 | mezen
# Processing Record 47 of Set 11 | west lorne
# Processing Record 48 of Set 11 | alzey
# Processing Record 49 of Set 11 | uk
# City not found. Skipping...
# Processing Record 50 of Set 11 | camacha
# Processing Record 1 of Set 12 | onega
# Processing Record 2 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | praia
# Processing Record 5 of Set 12 | zambrow
# Processing Record 6 of Set 12 | dondo
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | ouro preto do oeste
# Processing Record 9 of Set 12 | narrabri
# Processing Record 10 of Set 12 | radchenko
# Processing Record 11 of Set 12 | kanigoro
# Processing Record 12 of Set 12 | estelle
# Processing Record 13 of Set 12 | stokmarknes
# Processing Record 14 of Set 12 | sinop
# Processing Record 15 of Set 12 | gamba
# Processing Record 16 of Set 12 | nguru
# Processing Record 17 of Set 12 | yacuiba
# Processing Record 18 of Set 12 | puerto colombia
# Processing Record 19 of Set 12 | vytegra
# Processing Record 20 of Set 12 | samarkand
# Processing Record 21 of Set 12 | hammerfest
# Processing Record 22 of Set 12 | gandiaye
# Processing Record 23 of Set 12 | karwar
# Processing Record 24 of Set 12 | the valley
# Processing Record 25 of Set 12 | katsina
# Processing Record 26 of Set 12 | bilma
# Processing Record 27 of Set 12 | sergeyevka
# Processing Record 28 of Set 12 | mabay
# Processing Record 29 of Set 12 | guerrero negro
# Processing Record 30 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 12 | san carlos de bariloche
# Processing Record 32 of Set 12 | tezu
# Processing Record 33 of Set 12 | lazaro cardenas
# Processing Record 34 of Set 12 | atyrau
# Processing Record 35 of Set 12 | palasa
# City not found. Skipping...
# Processing Record 36 of Set 12 | ugoofaaru
# Processing Record 37 of Set 12 | hlotse
# City not found. Skipping...
# Processing Record 38 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 39 of Set 12 | menongue
# Processing Record 40 of Set 12 | redlands
# Processing Record 41 of Set 12 | syktyvkar
# Processing Record 42 of Set 12 | australind
# Processing Record 43 of Set 12 | kitimat
# Processing Record 44 of Set 12 | mildura
# Processing Record 45 of Set 12 | bima
# Processing Record 46 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 12 | ikryanoye
# Processing Record 48 of Set 12 | shiliguri
# Processing Record 49 of Set 12 | ranong
# Processing Record 50 of Set 12 | belen
# Processing Record 1 of Set 13 | aquiraz
# Processing Record 2 of Set 13 | pingliang
# Processing Record 3 of Set 13 | tanggu
# City not found. Skipping...
# Processing Record 4 of Set 13 | idritsa
# Processing Record 5 of Set 13 | skibbereen
# Processing Record 6 of Set 13 | yinchuan
# Processing Record 7 of Set 13 | hokitika
# Processing Record 8 of Set 13 | northam
# Processing Record 9 of Set 13 | camapua
# Processing Record 10 of Set 13 | krasavino
# Processing Record 11 of Set 13 | kyshtovka
# Processing Record 12 of Set 13 | juneau
# Processing Record 13 of Set 13 | santa lucia
# Processing Record 14 of Set 13 | mayumba
# Processing Record 15 of Set 13 | biggar
# Processing Record 16 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 13 | phun phin
# City not found. Skipping...
# Processing Record 18 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 13 | ahipara
# Processing Record 20 of Set 13 | bayan
# Processing Record 21 of Set 13 | zarand
# Processing Record 22 of Set 13 | vestmanna
# Processing Record 23 of Set 13 | road town
# Processing Record 24 of Set 13 | riyadh
# Processing Record 25 of Set 13 | morwell
# Processing Record 26 of Set 13 | campbeltown
# Processing Record 27 of Set 13 | batagay
# Processing Record 28 of Set 13 | pokrovsk
# Processing Record 29 of Set 13 | kismayo
# City not found. Skipping...
# Processing Record 30 of Set 13 | novikovo
# Processing Record 31 of Set 13 | muros
# Processing Record 32 of Set 13 | humen
# Processing Record 33 of Set 13 | necochea
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Cape Town -33.93   18.42     66.00        82          90        6.93
# 1        Rikitea -23.12 -134.97     73.99        85          93       20.33
# 2        Ushuaia -54.81  -68.31     50.00        61          75        4.70
# 3    New Norfolk -42.78  147.06     73.40        38          85       24.16
# 4           Kaeo -35.10  173.78     55.00       100         100       19.55
# ..           ...    ...     ...       ...       ...         ...         ...
# 555     Pokrovsk  61.48  129.14     -1.54        83          99        6.78
# 556     Novikovo  51.15   37.89     41.11        90           3       12.10
# 557        Muros  42.77   -9.06     55.00       100          75        2.24
# 558        Humen  22.82  113.67     84.99        51          20        8.05
# 559     Necochea -38.55  -58.74     55.99        95          44        7.00
#
#     Country                 Date Current Main      Current Description  \
# 0        ZA  2019-11-11 07:06:56       Clouds          overcast clouds
# 1        PF  2019-11-11 07:06:56         Rain               light rain
# 2        AR  2019-11-11 07:06:46       Clouds            broken clouds
# 3        AU  2019-11-11 07:06:57       Clouds          overcast clouds
# 4        NZ  2019-11-11 07:06:57         Rain               light rain
# ..      ...                  ...          ...                      ...
# 555      RU  2019-11-11 07:10:13       Clouds          overcast clouds
# 556      RU  2019-11-11 07:10:14        Clear                clear sky
# 557      ES  2019-11-11 07:10:14      Drizzle  light intensity drizzle
# 558      CN  2019-11-11 07:10:15       Clouds               few clouds
# 559      AR  2019-11-11 07:08:57       Clouds         scattered clouds
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.00                         0
# 1                        0.63                         0
# 2                        0.00                         0
# 3                        0.00                         0
# 4                        1.94                         0
# ..                        ...                       ...
# 555                      0.00                         0
# 556                      0.00                         0
# 557                      0.00                         0
# 558                      0.00                         0
# 559                      0.00                         0
#
# [560 rows x 13 columns]

# %%
# Determine datatpyes for DataFrame
city_data_df.dtypes
# Out:
# City                         object
# Lat                         float64
# Lng                         float64
# Max Temp                    float64
# Humidity                      int64
# Cloudiness                    int64
# Wind Speed                  float64
# Country                      object
# Date                         object
# Current Main                 object
# Current Description          object
# Rain inches (last 3 hrs)    float64
# Snow inches (last 3 hrs)      int64
# dtype: object

# %%
# Covert Snow integer type to float
city_data_df['Snow inches (last 3 hrs)'] = city_data_df['Snow inches (last 3 hrs)'].astype(float)
city_data_df['Snow inches (last 3 hrs)'].dtype
# Out:
# dtype('float64')

# %%
# reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain inches (last 3 hrs)", "Snow inches (last 3 hrs)"]

# %%
# Reordered DataFrame
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0    Cape Town      ZA  2019-11-11 07:06:56 -33.93   18.42     66.00
# 1      Rikitea      PF  2019-11-11 07:06:56 -23.12 -134.97     73.99
# 2      Ushuaia      AR  2019-11-11 07:06:46 -54.81  -68.31     50.00
# 3  New Norfolk      AU  2019-11-11 07:06:57 -42.78  147.06     73.40
# 4         Kaeo      NZ  2019-11-11 07:06:57 -35.10  173.78     55.00
# 5     Hermanus      ZA  2019-11-11 07:06:57 -34.42   19.24     69.01
# 6        Tiksi      RU  2019-11-11 07:06:58  71.64  128.87     -4.06
# 7        Arlit      NE  2019-11-11 07:06:58  18.74    7.39     77.97
# 8  East London      ZA  2019-11-11 07:06:58 -33.02   27.91     64.40
# 9       Albany      US  2019-11-11 07:06:58  42.65  -73.75     41.00
#
#    Humidity  Cloudiness  Wind Speed      Current Description  \
# 0        82          90        6.93          overcast clouds
# 1        85          93       20.33               light rain
# 2        61          75        4.70            broken clouds
# 3        38          85       24.16          overcast clouds
# 4       100         100       19.55               light rain
# 5        80          94        8.01            moderate rain
# 6        98         100        2.53               light snow
# 7        15          10        2.73                clear sky
# 8        93          90       14.99  light intensity drizzle
# 9        64          90        1.48          overcast clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.63                       0.0
# 2                      0.00                       0.0
# 3                      0.00                       0.0
# 4                      1.94                       0.0
# 5                      3.25                       0.0
# 6                      0.00                       0.0
# 7                      0.00                       0.0
# 8                      0.00                       0.0
# 9                      0.00                       0.0

# %%
# Create the output file (CSV)
output_data_file = "weather_data/M6_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="Weather_Challenge")

# %%
# How many cities have recorded rainfall or snow?
# Identify the cities have rain >0 or rain >0

wet_cities = city_data_df.loc[(city_data_df["Rain inches (last 3 hrs)"] > 0)   | \
                                  (city_data_df["Snow inches (last 3 hrs)"] > 0)   ].count()["City"]
wet_cities.astype(str)
f"There are {wet_cities} rainy/snowy cities"
# Out:
# 'There are 59 rainy/snowy cities'
